# %%
mov <- read.csv('moviesData.csv')

# %%
mov
# Out:
#     X   title                         title_type   genre
# 1    1  Filly Brown                   Feature Film Drama
# 2    2  The Dish                      Feature Film Drama
# 3    3  Waiting for Guffman           Feature Film Comedy
# 4    4  The Age of Innocence          Feature Film Drama
# 5    5  Malevolence                   Feature Film Horror
# 6    6  Old Partner                   Documentary  Documentary
# 7    7  Lady Jane                     Feature Film Drama
# 8    8  Mad Dog Time                  Feature Film Drama
# 9    9  Beauty Is Embarrassing        Documentary  Documentary
# 10  10  The Snowtown Murders          Feature Film Drama
# 11  11  Superman II                   Feature Film Action & Adventure
# 12  12  Leap of Faith                 Feature Film Drama
# 13  13  The Royal Tenenbaums          Feature Film Comedy
# 14  14  School for Scoundrels         Feature Film Comedy
# 15  15  Rhinestone                    Feature Film Comedy
# ...

# %%
# if - else statements 

inscore <- c(320,400,290)
ausscore <- c(320,400,290)

if(inscore[1] > ausscore[1]){
    print("India Won the 1st ODI!")
}else if(inscore[1] == ausscore[1]){
    print("Match tie!")
}else{
    print("Australia Won the 1st ODI!")
}
if(inscore[2] > ausscore[2]){
    print("India Won the 2nd ODI!")
}else if(inscore[1] == ausscore[1]){
    print("Match tie!")
}else{
    print("Australia Won the 2nd ODI!")
}
ifelse(inscore[3] > ausscore[3],"India Won the 3rd ODI!",ifelse(inscore[3]==ausscore[3],"Match tie!","Australia Won the 3rd ODI!"))
# Out:
# [1] "Match tie!"
# [1] "Match tie!"
# [1] "Match tie!"

# %%
mov$dev <- ifelse(mov$audience_score > mov$critics_score,1,0)

# %%
mov
# Out:
#     X   title                         title_type   genre
# 1    1  Filly Brown                   Feature Film Drama
# 2    2  The Dish                      Feature Film Drama
# 3    3  Waiting for Guffman           Feature Film Comedy
# 4    4  The Age of Innocence          Feature Film Drama
# 5    5  Malevolence                   Feature Film Horror
# 6    6  Old Partner                   Documentary  Documentary
# 7    7  Lady Jane                     Feature Film Drama
# 8    8  Mad Dog Time                  Feature Film Drama
# 9    9  Beauty Is Embarrassing        Documentary  Documentary
# 10  10  The Snowtown Murders          Feature Film Drama
# 11  11  Superman II                   Feature Film Action & Adventure
# 12  12  Leap of Faith                 Feature Film Drama
# 13  13  The Royal Tenenbaums          Feature Film Comedy
# 14  14  School for Scoundrels         Feature Film Comedy
# 15  15  Rhinestone                    Feature Film Comedy
# ...

# %%
# method to count any no of  desired data from any dataframe    sum() along with ifelse()
sum(ifelse(mov$audience_score > mov$critics_score ,1,0))
# Out:
# [1] 312

# %% [markdown]
# # Assignment

# %% [markdown]
# 1. Use the built-in data set iris. Find the Species, in which Sepal.Length is greater than Petal.Length.
# 2. Count all such Species.

# %%
# 1

data <- iris

data$SPL <- ifelse(data$Sepal.Length > data$Petal.Length,1,0)
data
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species   SPL
# 1   5.1          3.5         1.4          0.2         setosa    1
# 2   4.9          3.0         1.4          0.2         setosa    1
# 3   4.7          3.2         1.3          0.2         setosa    1
# 4   4.6          3.1         1.5          0.2         setosa    1
# 5   5.0          3.6         1.4          0.2         setosa    1
# 6   5.4          3.9         1.7          0.4         setosa    1
# 7   4.6          3.4         1.4          0.3         setosa    1
# 8   5.0          3.4         1.5          0.2         setosa    1
# 9   4.4          2.9         1.4          0.2         setosa    1
# 10  4.9          3.1         1.5          0.1         setosa    1
# 11  5.4          3.7         1.5          0.2         setosa    1
# 12  4.8          3.4         1.6          0.2         setosa    1
# 13  4.8          3.0         1.4          0.1         setosa    1
# ...

# %%
sum(ifelse(data$Sepal.Length > data$Petal.Length,1,0))
# Out:
# [1] 150
